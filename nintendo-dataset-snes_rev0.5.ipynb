# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

import pandas as pd
import warnings
import unidecode


warnings.filterwarnings('ignore')
import time, sys

def timeit(method):
    """
    Decorator: Compute the execution time of a function
    :param method: the function
    :return: the method runtime
    """

    def timed(*arguments, **kw):
        ts = time.time()
        result = method(*arguments, **kw)
        te = time.time()

        sys.stdout.write('Time:  %r %2.2f sec\n' % (method.__name__.strip("_"), te - ts))
        sys.stdout.write('------------------------------------\n')
        sys.stdout.flush()
        return result

    return timed

# %%
def remove_non_ascii(text):

    return ''.join(i for i in text if ord(i)<128)

# %%
driver = webdriver.Chrome('/Users/federico/Documents/datascience/jupyter/chromedriver')

# %%
@timeit
def get_games(games_url):
    game_list = []
    
    driver.get(games_url)
    games = driver.find_elements_by_xpath('//td[@class="name"]')
    for p in range(len(games)):
        game_list.append(games[p].text.split('\n')[0])

    return game_list

# %%
@timeit
def get_gametable_data(system_url, game_list):
    dev_list = []
    gen_list = []
    ser_list = []

    for game in game_list:
        driver.get(system_url)
        try:
            driver.find_element_by_link_text(game).click()
            gametable = driver.find_elements_by_xpath('//table[@class="gameDataTable"]')

            st = gametable[0].text.split('\n')
            try:
                dev_list.append(' '.join(st[1].split()[1:]))
            except IndexError:
                dev_list.append(None)
            try:
                gen_list.append(' '.join(st[2].split()[1:]))
            except IndexError:
                gen_list.append(None)
            try:
                ser_list.append(' '.join(st[3].split()[1:]))
            except IndexError:
                ser_list.append(None)
        except NoSuchElementException:
            dev_list.append(None)
            gen_list.append(None)
            ser_list.append(None)
    return dev_list, gen_list, ser_list

# %%
@timeit
def get_releasetable_data(system_url, game_list, region):
    jap_name = []
    jap_date = []
    us_name = []
    us_date = []
    eu_name = []
    eu_date = []


    for game in game_list:
        #if game ==  'F-Zero':
         #   jap_name.append('F-Zero')
          #  jap_date.append(None)
           # us_name.append('F-Zero')
            #us_date.append(None)
            #eu_name.append('F-Zero')
            #eu_date.append(None)
            #continue

            
        driver.get(system_url)
        try:
            driver.find_element_by_link_text(game).click()
            release_table = driver.find_elements_by_xpath('//table[@class="gameRelease"]')[0]

            release_table = release_table.text.split('\n')[1:]
            release_flags = driver.find_elements_by_xpath('//td[@class="flag"]')
            if len(release_flags) > 3:
                release_flags = release_flags[:3]

            countries = []

            for flag in release_flags:
                country = flag.find_element_by_tag_name('img').get_attribute('src')[-6:-4]
                countries.append(country)



            if len(release_table) % 2 != 0:
                if len(countries) == 1:
                    if countries[0] == 'jp':
                        jap_name.append(release_table[0])
                        jap_date.append(release_table[2])
                        us_name.append(None)
                        us_date.append(None)
                        eu_name.append(None)
                        eu_date.append(None)
                   
                    elif countries[0] == 'us':
                        jap_name.append(None)
                        jap_date.append(None)
                        us_name.append(release_table[0])
                        us_date.append(release_table[2])
                        eu_name.append(None)
                        eu_date.append(None)
                    elif countries[0] == 'eu':
                        jap_name.append(None)
                        jap_date.append(None)
                        us_name.append(None)
                        us_date.append(None)
                        eu_name.append(release_table[0])
                        eu_date.append(release_table[2])


                elif len(countries) == 2:
                    if countries[0] == 'jp':
                        jap_name.append(release_table[0])
                        jap_date.append(release_table[2])
                        if countries[1] == 'us':
                            us_name.append(release_table[3])
                            us_date.append(release_table[4])
                            eu_name.append(None)
                            eu_date.append(None)
                        else:
                            eu_name.append(release_table[3])
                            eu_date.append(release_table[4])
                            us_name.append(None)
                            us_date.append(None)

                    if countries[0] == 'us':
                        us_name.append(release_table[0])
                        us_date.append(release_table[1])

                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])

                            jap_date.append(release_table[4])
                            eu_name.append(None)
                            eu_date.append(None)
                        else:
                            eu_name.append(release_table[2])
                            eu_date.append(release_table[3])
                            jap_name.append(None)
                            jap_date.append(None)

                    if countries[0] == 'eu':
                        eu_name.append(release_table[0])
                        eu_date.append(release_table[1])
                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])
                            jap_date.append(release_table[4])
                            us_name.append(None)
                            us_date.append(None)
                        else:
                            us_name.append(release_table[2])
                            us_date.append(release_table[3])
                            jap_name.append(None)
                            jap_date.append(None)


                elif len(countries) == 3:
                    if countries[0] == 'jp':
                        jap_name.append(release_table[0])
                        jap_date.append(release_table[2])

                        if countries[1] == 'us':
                            us_name.append(release_table[3])
                            us_date.append(release_table[4])
                            eu_name.append(release_table[5])
                            eu_date.append(release_table[6])
                        else:
                            eu_name.append(release_table[3])
                            eu_date.append(release_table[4])
                            us_name.append(release_table[5])

                            us_date.append(release_table[6])


                    elif countries[0] == 'us':
                        us_name.append(release_table[0])

                        us_date.append(release_table[1])

                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])
                            jap_date.append(release_table[4])
                            eu_name.append(release_table[5])
                            eu_date.append(release_table[6])

                        else:
                            eu_name.append(release_table[2])

                            eu_date.append(release_table[3])

                            jap_name.append(release_table[4])

                            jap_date.append(release_table[6])


                    elif countries[0] == 'eu':
                        eu_name.append(release_table[0])

                        eu_date.append(release_table[1])

                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])

                            jap_date.append(release_table[4])
                            us_name.append(release_table[5])

                            us_date.append(release_table[6])

                        else:
                            us_name.append(release_table[2])
                            us_date.append(release_table[3])
                            jap_name.append(release_table[4])
                            jap_date.append(release_table[6])
                            
            else: #casi F-Zero
                
                if len(countries) == 1:
                    if countries[0] == 'jp':
                        jap_name.append(release_table[0])
                        jap_date.append(release_table[1])
                        us_name.append(None)
                        us_date.append(None)
                        eu_name.append(None)
                        eu_date.append(None)

                    elif countries[0] == 'us':
                        jap_name.append(None)
                        jap_date.append(None)
                        us_name.append(release_table[0])
                        us_date.append(release_table[1])
                        eu_name.append(None)
                        eu_date.append(None)
                    elif countries[0] == 'eu':
                        jap_name.append(None)
                        jap_date.append(None)
                        us_name.append(None)
                        us_date.append(None)
                        eu_name.append(release_table[0])
                        eu_date.append(release_table[1])


                elif len(countries) == 2:
                    if countries[0] == 'jp':
                        jap_name.append(release_table[0])
                        jap_date.append(release_table[1])
                        if countries[1] == 'us':
                            us_name.append(release_table[2])
                            us_date.append(release_table[3])
                            eu_name.append(None)
                            eu_date.append(None)
                        else:
                            eu_name.append(release_table[2])
                            eu_date.append(release_table[3])
                            us_name.append(None)
                            us_date.append(None)

                    if countries[0] == 'us':
                        us_name.append(release_table[0])
                        us_date.append(release_table[1])

                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])

                            jap_date.append(release_table[3])
                            eu_name.append(None)
                            eu_date.append(None)
                        else:
                            eu_name.append(release_table[2])
                            eu_date.append(release_table[3])
                            jap_name.append(None)
                            jap_date.append(None)

                    if countries[0] == 'eu':
                        eu_name.append(release_table[0])
                        eu_date.append(release_table[1])
                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])
                            jap_date.append(release_table[3])
                            us_name.append(None)
                            us_date.append(None)
                        else:
                            us_name.append(release_table[2])
                            us_date.append(release_table[3])
                            jap_name.append(None)
                            jap_date.append(None)


                elif len(countries) == 3:
                    if countries[0] == 'jp':
                        jap_name.append(release_table[0])
                        jap_date.append(release_table[1])

                        if countries[1] == 'us':
                            us_name.append(release_table[2])
                            us_date.append(release_table[3])
                            eu_name.append(release_table[4])
                            eu_date.append(release_table[5])
                        else:
                            eu_name.append(release_table[2])
                            eu_date.append(release_table[3])
                            us_name.append(release_table[4])

                            us_date.append(release_table[5])


                    elif countries[0] == 'us':
                        us_name.append(release_table[0])

                        us_date.append(release_table[1])

                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])
                            jap_date.append(release_table[3])
                            eu_name.append(release_table[4])
                            eu_date.append(release_table[5])

                        else:
                            eu_name.append(release_table[2])

                            eu_date.append(release_table[3])

                            jap_name.append(release_table[4])

                            jap_date.append(release_table[5])


                    elif countries[0] == 'eu':
                        eu_name.append(release_table[0])

                        eu_date.append(release_table[1])

                        if countries[1] == 'jp':
                            jap_name.append(release_table[2])

                            jap_date.append(release_table[3])
                            us_name.append(release_table[4])

                            us_date.append(release_table[5])

                        else:
                            us_name.append(release_table[2])
                            us_date.append(release_table[3])
                            jap_name.append(release_table[4])
                            jap_date.append(release_table[5])
                            
                            
                            
                            
                            
        except (IndexError, NoSuchElementException):
        
            if region == 'jp':      
                jap_name.append(game)
                jap_date.append(None)
                us_name.append(None)
                us_date.append(None)
                eu_name.append(None)
                eu_date.append(None)
                print("Something wrong with game:", game)
            elif region == 'us':
                jap_name.append(None)
                jap_date.append(None)
                us_name.append(game)
                us_date.append(None)
                eu_name.append(None)
                eu_date.append(None)
                print("Something wrong with game:", game)
            elif region == 'eu':
                jap_name.append(None)
                jap_date.append(None)
                us_name.append(None)
                us_date.append(None)
                eu_name.append(game)
                eu_date.append(None)
                print("Something wrong with game:", game)
            
                
    return jap_name, jap_date, us_name, us_date, eu_name, eu_date

# %%
#@timeit

def getDev (game, df, w):
    print (game)
    roles = ['Executive', 'Sub', 'Design', 'Level', 'Programming', 'Assistant', 'Associate', 
             'Program', 'General', 'Chief']
    producer_flag = False
    director_flag = False
    
    title = remove_non_ascii(game)
            
    if title.startswith("the-"):
        title = title[4:]
                              
    driver.get("https://www.mobygames.com/game/wii/" + title + "/credits")
    devs = driver.find_elements_by_xpath('//tr[@class="crln"]')
    for d in devs:
        
        if producer_flag == False:
            role_check = True
            if 'Producer' in d.text:
                for role in roles:
                    if role in d.text:
                        role_check = False
                if role_check == True:
                    df['Producer'][w] = str(d.text).replace('Producers', '').replace('Producer', "").replace('Lead', "")
                    producer_flag = True
                    
        if director_flag == False:
            role_check = True
            if 'Director' in d.text:
                for role in roles:
                    if role in d.text:
                        role_check = False
                if role_check == True:
                    df['Director'][w] = str(d.text).replace('Game', '').replace('Directors', '').replace('Director', "").replace('Lead', "")
                    director_flag = True
                    
        if producer_flag == True and director_flag == True:
            break
    
    if producer_flag == False:
        driver.get("http://kyoto-report.wikidot.com/" + game)

        devs = driver.find_elements_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/div/div[3]/table[2]/tbody/tr/td[2]/p[1]')
        
        if len(devs) > 0:
            producer_list = str(devs[0].text).split('\n⌂ ')
            producer_value = ""
            for k in range(1,len(producer_list)-1):
                producer_value = producer_value + producer_list[k].split('\n')[0] + ", "
            producer_value = producer_value + producer_list[len(producer_list)-1].split('\n')[0] 
            df['Producer'][w] = producer_value
            
            if len(producer_list) == 2:
                producer_value = producer_list[1].split('\n')[0]
            producer_flag = True
    
    if producer_flag == False:
        driver.get("http://kyoto-report.wikidot.com/" + game + "-credits")
        devs = driver.find_elements_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/div/div[3]/p[2]')
        
        if len(devs) > 0:
            producer_list = devs[0].text.split('\n⌂ ')
            producer_value = ""

            for k in range(1,len(producer_list)-1):
                producer_value = producer_value + producer_list[k].split('\n')[0] + ", "
                producer_value = producer_value + producer_list[len(producer_list)-1].split('\n')[0] 
                
            if len(producer_list) == 2:
                producer_value = producer_list[1].split('\n')[0]
            
            df['Producer'][w] = producer_value
            producer_flag = True

    if director_flag == False:
        driver.get("http://kyoto-report.wikidot.com/" + game)

        devs = driver.find_elements_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/div/div[3]/table[2]/tbody/tr/td[1]/p[1]')
        
        if len(devs) > 0:

            director_list = str(devs[0].text).split('\n⌂ ')
            director_value = ""
            for j in range(1,len(director_list)-1):
                director_value = director_value + director_list[j].split('\n')[0] + ", "
            director_value = director_value + director_list[len(director_list)-1].split('\n')[0] 
            if len(director_list) == 2:
                director_value = director_list[1].split('\n')[0]
            df['Director'][w] = director_value

            director_flag = True
        
    if director_flag == False:
        director_list = []
        director_value = ""

        driver.get("http://kyoto-report.wikidot.com/" + game + "-credits")
        devs = driver.find_elements_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/div/div[3]/p[3]')
       
        if len(devs) > 0:
            director_list = devs[0].text.split('\n⌂ ')
            for k in range(1,len(director_list)-1):
                director_value = director_value + director_list[k].split('\n')[0] + ", "
                director_value = director_value + director_list[len(director_list)-1].split('\n')[0]   
                if len(director_list) == 2:
                    director_value = director_list[1].split('\n')[0]                
                df['Director'][w] = director_value
                
                director_flag = True


    return df

# %%
@timeit
def main():
    # snes, gb, gbc
    super_famicom_url = 'https://nindb.net/wii/games-jp.html'
    pw_url = "https://nindb.net/snes/np-jp.html"
    us_url = 'https://nindb.net/snes/games-us.html'
    # gbc = 'https://nindb.net/gb/gbcolor-jp.html'
    
    # SUPER FAMICOM
    print('Getting game titles...')
    game_list = get_games(super_famicom_url)[0:15]
    game_list_pw = [g for g in get_games(pw_url) if g not in game_list][0:15]
    #game_list_us = [g for g in get_games(us_url) if g not in game_list]
    print('Getting release data...')
    jap_name, jap_date, us_name, us_date, eu_name, eu_date = get_releasetable_data(super_famicom_url, game_list, 'jp')
    jap_name_pw, jap_date_pw, us_name_pw, us_date_pw, eu_name_pw, eu_date_pw = get_releasetable_data(pw_url, game_list_pw, 'jp')
    #jap_name_us, jap_date_us, us_name_us, us_date_us, eu_name_us, eu_date_us = get_releasetable_data(us_url, game_list_us, 'usa')
    print('Getting game data...')
    dev_list, gen_list, ser_list = get_gametable_data(super_famicom_url, game_list)
    dev_list_pw, gen_list_pw, ser_list_pw = get_gametable_data(pw_url, game_list_pw)
    #dev_list_us, gen_list_us, ser_list_us = get_gametable_data(us_url, game_list_us)

    #game_list_us = [g for g in get_games(us_url) if g not in us_name]
    #jap_name_us, jap_date_us, us_name_us, us_date_us, eu_name_us, eu_date_us = get_releasetable_data(us_url, game_list_us, 'us')
    #dev_list_us, gen_list_us, ser_list_us = get_gametable_data(us_url, game_list_us)
    

    #try:
    print('Building dataframe...')
    df = pd.DataFrame()
    df['JP Title'] = game_list + game_list_pw #+ jap_name_us
    df['JP Release Date'] = jap_date + jap_date_pw #+ jap_date_us
    df['US Title'] = us_name + us_name_pw #+ us_name_us
    df['US Release Date'] = us_date + us_date_pw #+ us_date_us
    df['EU Title'] = eu_name + eu_name_pw #+ eu_name_us
    df['EU Release Date'] = eu_date + eu_date_pw #+ eu_date_us

    df['System'] = ["SFC"] * len(df)
    df['Developer'] = dev_list + dev_list_pw #+ dev_list_us
    df['Genre'] = gen_list + gen_list_pw #+ gen_list_us
    df['Series'] = ser_list + ser_list_pw #+ ser_list_us
    #except:
        #return jap_name_us, jap_date_us, us_name_us, us_date_us, eu_name_us, eu_date_us
        
    
    print('Getting developers data...')

    df['Producer'] = [None] * len(df)
    df['Director'] = [None] * len(df)
    for w in range(len(df)):
        if df['JP Title'][w] == 'Mario no Super Picross':
            df['US Title'][w] = "Mario's Super Picross"
            df['EU Title'][w] = df['US Title'][w]

            
        if df['US Title'][w] is not None:
            title = (df['US Title'][w]).lower().replace(' & ', '-').replace(' ', '-').replace(':-', '-').replace("'", '').replace("ū", '').replace(".", '').replace("!", '').replace("ō", '')
            if title == 'star-fox':
                title = 'star-fox_'
            elif title == 'battleclash':
                title = 'battle-clash'
            df = getDev (title, df, w)
        elif df['EU Title'][w] is not None:
            title = (df['EU Title'][w]).lower().replace(' & ', '-').replace(' ', '-').replace(':-', '-').replace("'", '').replace("ū", '').replace(".", '').replace("!", '').replace("ō", '')
            df = getDev (title, df, w)
        elif df['JP Title'][w] is not None:
            title = (df['JP Title'][w]).lower().replace(' & ', '-').replace(' ', '-').replace(':-', '-').replace("'", '').replace("ū", '').replace(".", '').replace("!", '').replace("ō", '')

            df = getDev (title, df, w)
    
    
    print('Done!')
    return df

# %%
#'famicom-tantei' in'famicom-tantei-club-ushiro-ni-tatsu-shjo'

# %%
df  = main()
# Out:
# Getting game titles...
# Time:  'get_games' 1.31 sec
# ------------------------------------
# Time:  'get_games' 0.69 sec
# ------------------------------------
# Getting release data...
# Time:  'get_releasetable_data' 6.98 sec
# ------------------------------------
# Time:  'get_releasetable_data' 6.00 sec
# ------------------------------------
# Getting game data...
# Time:  'get_gametable_data' 2.08 sec
# ------------------------------------
# Time:  'get_gametable_data' 2.15 sec
# ------------------------------------
# Building dataframe...
# Getting developers data...
# wii-play
# warioware-smooth-moves
# wii-sports
# the-legend-of-zelda-twilight-princess
# pokémon-battle-revolution
# excite-truck
# fire-emblem-radiant-dawn
# eyeshield-21-field-saiky-no-senshi-tachi
# super-paper-mario
# big-brain-academy-wii-degree
# donkey-kong-barrel-blast
# mario-party-8
# endless-ocean
# mario-strikers-charged
# super-mario-galaxy
# f-zero
# fire-emblem-monsh-no-nazo
# fire-emblem-seisen-no-keifu
# kirbys-dream-course
# marios-super-picross
# earthbound
# panel-de-pon
# sim-city
# donkey-kong-country
# donkey-kong-country-2-diddys-kong-quest
# donkey-kong-country-3-dixie-kongs-double-trouble
# super-mario-all-stars
# super-mario-world
# super-metroid
# heisei-shin-onigashima-–-zenpen
# Done!
# Time:  'main' 65.18 sec
# ------------------------------------

# %%
df
# Out:
#                                        JP Title          JP Release Date  \
# 0                               Hajimete no Wii              02 Dec 2006
# 1                           Odoru Made in Wario              02 Dec 2006
# 2                                    Wii Sports              02 Dec 2006
# 3          Zelda no Densetsu: Twilight Princess  02 Dec 2006 02 Dec 2006
# 4                     Pokémon Battle Revolution              14 Dec 2006
# 5                                  Excite Truck              18 Jan 2007
# 6               Fire Emblem: Akatsuki no Megami              22 Feb 2007
# 7   Eyeshield 21: Field Saikyō no Senshi-Tachi              08 Mar 2007
# 8                             Super Paper Mario              19 Apr 2007
# 9                    Wii de Yawaraka Atama Juku              26 Apr 2007
# 10                   Donkey Kong: Taru Jet Race              28 Jun 2007
# 11                                Mario Party 8              26 Jul 2007
# 12                                 Forever Blue              02 Aug 2007
# 13                       Mario Strikers Charged              20 Sep 2007
# 14                           Super Mario Galaxy              01 Nov 2007
# 15                                       F-Zero              21 Nov 1990
# 16                 Fire Emblem: Monshō no Nazo              21 Jan 1994
# 17                 Fire Emblem: Seisen no Keifu              14 May 1996
# 18                                   Kirby Bowl              21 Sep 1994
# 19                       Mario no Super Picross              14 Sep 1995
# 20                Mother 2: Giegue no Gyakushū              27 Aug 1994
# 21                                 Panel de Pon              27 Oct 1995
# 22                                      SimCity              26 Apr 1991
# 23                            Super Donkey Kong              26 Nov 1994
# 24           Super Donkey Kong 2: Diddy & Dixie              21 Nov 1995
# 25    Super Donkey Kong 3: Nazo no Kremis Shima              23 Nov 1996
# 26                       Super Mario Collection              14 Jul 1993
# 27                            Super Mario World              21 Nov 1990
# 28                                Super Metroid              19 Mar 1994
# 29             Heisei: Shin Onigashima – Zenpen  01 Dec 1997 01 Dec 1997
#
#                                              US Title  \
# 0                                            Wii Play
# 1                             WarioWare: Smooth Moves
# 2                                          Wii Sports
# 3              The Legend of Zelda: Twilight Princess
# 4                           Pokémon Battle Revolution
# 5                                        Excite Truck
# 6                           Fire Emblem: Radiant Dawn
# 7                                                None
# 8                                   Super Paper Mario
# 9                       Big Brain Academy: Wii Degree
# 10                          Donkey Kong: Barrel Blast
# 11                                      Mario Party 8
# 12                                      Endless Ocean
# 13                             Mario Strikers Charged
# 14                                 Super Mario Galaxy
# 15                                             F-Zero
# 16                                               None
# 17                                               None
# 18                               Kirby's Dream Course
# 19                              Mario's Super Picross
# 20                                         EarthBound
# 21                                               None
# 22                                           Sim City
# 23                                Donkey Kong Country
# 24          Donkey Kong Country 2: Diddy's Kong Quest
# 25  Donkey Kong Country 3: Dixie Kong's Double Tro...
# 26                              Super Mario All-Stars
# 27                                  Super Mario World
# 28                                      Super Metroid
# 29                                               None
#
#             US Release Date  \
# 0               12 Feb 2007
# 1               15 Jan 2007
# 2               19 Nov 2006
# 3   19 Nov 2006 11 Dec 2006
# 4               26 Jun 2007
# 5               19 Nov 2006
# 6               05 Nov 2007
# 7                      None
# 8               09 Apr 2007
# 9               11 Jun 2007
# 10              08 Oct 2007
# 11              29 May 2007
# 12              21 Jan 2008
# 13              30 Jul 2007
# 14              12 Nov 2007
# 15                 Aug 1991
# 16                     None
# 17                     None
# 18                 Feb 1995
# 19                     None
# 20                 Jun 1995
# 21                     None
# 22                 Aug 1991
# 23                 Nov 1994
# 24                 Dec 1995
# 25                 Nov 1996
# 26                 Aug 1993
# 27                 Aug 1991
# 28                 Apr 1994
# 29                     None
#
#                                              EU Title  \
# 0                                            Wii Play
# 1                             WarioWare: Smooth Moves
# 2                                          Wii Sports
# 3              The Legend of Zelda: Twilight Princess
# 4                           Pokémon Battle Revolution
# 5                                        Excite Truck
# 6                           Fire Emblem: Radiant Dawn
# 7                                                None
# 8                                   Super Paper Mario
# 9                           Big Brain Academy for Wii
# 10                              Donkey Kong: Jet Race
# 11                                      Mario Party 8
# 12                                      Endless Ocean
# 13                    Mario Strikers Charged Football
# 14                                 Super Mario Galaxy
# 15                                             F-Zero
# 16                                               None
# 17                                               None
# 18                               Kirby's Dream Course
# 19                              Mario's Super Picross
# 20                                               None
# 21                                               None
# 22                                           Sim City
# 23                                Donkey Kong Country
# 24          Donkey Kong Country 2: Diddy's Kong Quest
# 25  Donkey Kong Country 3: Dixie Kong's Double Tro...
# 26                              Super Mario All-Stars
# 27                                  Super Mario World
# 28                                      Super Metroid
# 29                                               None
#
#             EU Release Date System                       Developer  \
# 0               08 Dec 2006    SFC                        Nintendo
# 1               12 Jan 2007    SFC   Nintendo, Intelligent Systems
# 2               08 Dec 2006    SFC                        Nintendo
# 3   08 Dec 2006 15 Dec 2006    SFC                        Nintendo
# 4               07 Dec 2007    SFC                 Genius Sonority
# 5               16 Feb 2007    SFC                   Monster Games
# 6               14 Mar 2008    SFC             Intelligent Systems
# 7                      None    SFC                        Nintendo
# 8               14 Sep 2007    SFC             Intelligent Systems
# 9               20 Jul 2007    SFC                        Nintendo
# 10              25 Jan 2008    SFC                            Paon
# 11              03 Aug 2007    SFC      Hudson Soft, CA Production
# 12              09 Nov 2007    SFC                           Arika
# 13              25 May 2007    SFC                Next Level Games
# 14              16 Nov 2007    SFC                        Nintendo
# 15                 Jun 1992    SFC                        Nintendo
# 16                     None    SFC             Intelligent Systems
# 17                     None    SFC             Intelligent Systems
# 18                 Aug 1995    SFC                  HAL Laboratory
# 19                     None    SFC                         Jupiter
# 20                     None    SFC                  HAL Laboratory
# 21                     None    SFC             Intelligent Systems
# 22                 Sep 1992    SFC                 Nintendo, Maxis
# 23                 Nov 1994    SFC                            Rare
# 24                 Dec 1995    SFC                            Rare
# 25                 Dec 1996    SFC                            Rare
# 26                 Dec 1993    SFC                        Nintendo
# 27                 Apr 1992    SFC                        Nintendo
# 28                 Jul 1994    SFC  Nintendo / Intelligent Systems
# 29                     None    SFC         Nintendo / Pax Softnica
#
#                         Genre                               Series  \
# 0                   Minigames                      Wii Play Series
# 1                   Minigames                   Super Mario Series
# 2                      Sports                    Wii Sports Series
# 3            Action Adventure           The Legend of Zelda Series
# 4                  RPG Battle                       Pokémon Series
# 5                      Racing                    Excitebike Series
# 6                Strategy RPG                   Fire Emblem Series
# 7   Sport (American Football)                  Eyeshield 21 Series
# 8                  Action RPG                   Super Mario Series
# 9        Education, Minigames             Big Brain Academy Series
# 10                     Racing                   Donkey Kong Series
# 11                 Party Game                   Super Mario Series
# 12                 Simulation                 Endless Ocean Series
# 13            Sports (Soccer)                   Super Mario Series
# 14                 Platformer                   Super Mario Series
# 15                     Racing                        F-Zero Series
# 16             Strategy / RPG                   Fire Emblem Series
# 17             Strategy / RPG                   Fire Emblem Series
# 18                 Crazy Golf                         Kirby Series
# 19                     Puzzle  Super Mario Series / Picross Series
# 20                        RPG           EarthBound (Mother) Series
# 21                     Puzzle                 Puzzle League Series
# 22                 Simulation                       SimCity Series
# 23                 Platformer                   Donkey Kong Series
# 24                 Platformer                   Donkey Kong Series
# 25                 Platformer                   Donkey Kong Series
# 26     Platformer Compilation                   Super Mario Series
# 27                 Platformer                   Super Mario Series
# 28        Action / Platformer                       Metroid Series
# 29                  Adventure       Famicom Mukashi Banashi Series
#
#                                              Producer  \
# 0                                      Katsuya Eguchi
# 1                 Yoshio Sakamoto, Ryouichi Kitanishi
# 2                                      Katsuya Eguchi
# 3                                    Shigeru Miyamoto
# 4                      Hiroyuki Jinnai, Hiroaki Tsuru
# 5                    Kensuke Tanabe, Keisuke Terasaki
# 6                     Toru Narihiro, Hitoshi Yamagami
# 7                                                None
# 8                  Kensuke Tanabe, Ryouichi Kitanishi
# 9                                     Hiroyuki Kimura
# 10   Kentaro Nishimura, Toshiharu Izuno, Rikiya Na...
# 11                        Hiroshi Sato, Atsushi Ikeda
# 12                    Ichirō Mihara, Hitoshi Yamagami
# 13                      Justin Dowdeswell, Ken Yeeloy
# 14                    Shigeru Miyamoto, Takao Shimizu
# 15                                   Shigeru Miyamoto
# 16                                               None
# 17                                               None
# 18                     Satoru Iwata, Shigeru Miyamoto
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                   Shigeru Miyamoto
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                   Shigeru Miyamoto
# 27                                   Shigeru Miyamoto
# 28                                        Makoto Kano
# 29                                               None
#
#                                              Director
# 0                                       Motoi Okamoto
# 1                                        Taku Sugioka
# 2    Keizo Ohta, Takayuki Shimamura, Yoshikazu Yam...
# 3                                         Eiji Aonuma
# 4                                       Manabu Yamana
# 5                                                None
# 6                                        Taeko Kaneda
# 7                                                None
# 8                                    Art  Chie Kawabe
# 9                                   Tomoaki Yoshinobu
# 10                                     Kenichi Imaeda
# 11                                  Shūichirō Nishiya
# 12                   Akira Kurabayashi, Masaki Tawara
# 13                                  Michael Inglehart
# 14                         Movie Scene  Masaki Yokobe
# 15                                               None
# 16                                               None
# 17                                               None
# 18                      Takao Shimizu, Yasuhiro Sakai
# 19                                               None
# 20                                               None
# 21                                               None
# 22                     Hideki Konno, Tadashi Sugiyama
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                     Takashi Tezuka
# 27                               Main  Takashi Tezuka
# 28                                    Yoshio Sakamoto
# 29                                               None

# %%
super_famicom_url = 'https://nindb.net/snes/games-jp.html'
game_list = df
jap_name, jap_date, us_name, us_date, eu_name, eu_date = get_releasetable_data(super_famicom_url, game_list, 'jp')
# Out:
# Time:  'get_releasetable_data' 0.34 sec
# ------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d9ac58cc34a4> in <module>
#       1 super_famicom_url = 'https://nindb.net/snes/games-jp.html'
#       2 game_list = df
# ----> 3 jap_name, jap_date, us_name, us_date, eu_name, eu_date = get_releasetable_data(super_famicom_url, game_list, 'jp')
#
# ValueError: too many values to unpack (expected 6)

# %%
df
# Out:
# ['Super Mario World',
#  'F-Zero',
#  'Pilotwings',
#  'SimCity',
#  'Zelda no Densetsu: Kamigami no Triforce',
#  'Mario Paint',
#  'Super Mario Kart',
#  'Star Fox',
#  'Super Scope 6',
#  'Super Scope Space Bazooka']

# %%
release_table

# %%
release_table
# Out:
# ['F-Zero', '21 Nov 1990', 'F-Zero', 'Aug 1991', 'F-Zero', 'Jun 1992']

# %%
df
# Out:
#                                        JP Title          JP Release Date  \
# 0                             Super Mario World              21 Nov 1990
# 1                                        F-Zero                     None
# 2                                    Pilotwings              21 Nov 1990
# 3                                       SimCity              26 Apr 1991
# 4       Zelda no Densetsu: Kamigami no Triforce              21 Nov 1991
# 5                                   Mario Paint              14 Jul 1992
# 6                              Super Mario Kart              27 Aug 1992
# 7                                      Star Fox              21 Feb 1993
# 8                                 Super Scope 6              18 Mar 1993
# 9                     Super Scope Space Bazooka              21 Jun 1993
# 10                       Super Mario Collection              14 Jul 1993
# 11                        Yoshi no Road Hunting              14 Jul 1993
# 12                                Mario & Wario              27 Aug 1993
# 13                 Fire Emblem: Monshō no Nazo              21 Jan 1994
# 14                                Super Metroid              19 Mar 1994
# 15                                    Wild Trax              04 Jun 1994
# 16                Mother 2: Giegue no Gyakushū              27 Aug 1994
# 17                                   Kirby Bowl              21 Sep 1994
# 18                            Super Donkey Kong              26 Nov 1994
# 19                    Super Mario: Yoshi Island              05 Aug 1995
# 20                       Mario no Super Picross              14 Sep 1995
# 21                                 Panel de Pon              27 Oct 1995
# 22           Super Donkey Kong 2: Diddy & Dixie              21 Nov 1995
# 23                              Super Mario RPG              09 Mar 1996
# 24                  Hoshi no Kirby Super Deluxe              21 Mar 1996
# 25                 Fire Emblem: Seisen no Keifu              14 May 1996
# 26          Marvelous: Mōhitotsu no Takarajima              26 Oct 1996
# 27    Super Donkey Kong 3: Nazo no Kremis Shima              23 Nov 1996
# 28          Itoi Shigesato no Bass Fishing No.1              21 Feb 1997
# 29             Heisei: Shin Onigashima – Zenpen  01 Dec 1997 01 Dec 1997
# 30             Heisei: Shin Onigashima – Kōhen  01 Dec 1997 01 Dec 1997
# 31                            Wrecking Crew '98              01 Jan 1998
# 32                       Kirby no Kirakira Kids              01 Feb 1998
# 33                               Power Sōkoban              01 Jan 1999
# 34                                 Sutte Hakkun              01 Aug 1998
# 35                     Fire Emblem: Thracia 776              01 Sep 1999
# 36                            Super Punch-Out!!              01 Mar 1998
# 37  Famicom Tantei Club: Ushiro Ni Tatsu Shōjo              01 Apr 1998
# 38                           Super Famicom Wars              01 May 1998
# 39                                    Dr. Mario              01 Jun 1998
# 40                              Zootto Mahjong!              01 Jul 1998
# 41                            Derby Stallion 98                     None
# 42            Mini 4WD: Let's & Go!! Power WGP2                     None
# 43                            Power Lode Runner              01 Jan 1999
# 44                             Picross NP Vol.1              01 Apr 1999
# 45                             Picross NP Vol.2              01 Apr 1999
# 46              Famicom Bunko: Hajimari no Mori              01 Jul 1999
# 47                             Picross NP Vol.3              01 Apr 1999
# 48                             Picross NP Vol.4              01 Apr 1999
# 49                             Picross NP Vol.5              01 Apr 1999
# 50                             Picross NP Vol.6              01 Apr 1999
# 51                             Picross NP Vol.7              01 Apr 1999
# 52                             Picross NP Vol.8              01 Apr 1999
# 53           Metal Slader Glory: Director's Cut                     None
#
#                                              US Title US Release Date  \
# 0                                   Super Mario World        Aug 1991
# 1                                              F-Zero            None
# 2                                          Pilotwings        Aug 1991
# 3                                            Sim City        Aug 1991
# 4             The Legend of Zelda: A Link to the Past        Apr 1992
# 5                                         Mario Paint        Aug 1992
# 6                                    Super Mario Kart        Sep 1992
# 7                                            Star Fox        Mar 1993
# 8                                       Super Scope 6        Feb 1992
# 9                                         BattleClash        Oct 1992
# 10                              Super Mario All-Stars        Aug 1993
# 11                                     Yoshi's Safari        Sep 1993
# 12                                               None            None
# 13                                               None            None
# 14                                      Super Metroid        Apr 1994
# 15                                      Stunt Race FX        Jul 1994
# 16                                         EarthBound        Jun 1995
# 17                               Kirby's Dream Course        Feb 1995
# 18                                Donkey Kong Country        Nov 1994
# 19                Super Mario World 2: Yoshi's Island        Oct 1995
# 20                              Mario's Super Picross            None
# 21                                      Tetris Attack            None
# 22          Donkey Kong Country 2: Diddy's Kong Quest        Dec 1995
# 23         Super Mario RPG: Legend of the Seven Stars        May 1996
# 24                                   Kirby Super Star        Sep 1996
# 25                                               None            None
# 26                                               None            None
# 27  Donkey Kong Country 3: Dixie Kong's Double Tro...        Nov 1996
# 28                                               None            None
# 29                                               None            None
# 30                                               None            None
# 31                                               None            None
# 32                                               None            None
# 33                                               None            None
# 34                                               None            None
# 35                                               None            None
# 36                                  Super Punch-Out!!        Oct 1994
# 37                                               None            None
# 38                                               None            None
# 39                                               None            None
# 40                                               None            None
# 41                                               None            None
# 42                                               None            None
# 43                                               None            None
# 44                                        01 Jun 1999    ピクロスNP Vol.3
# 45                                        01 Jun 1999    ピクロスNP Vol.3
# 46                                               None            None
# 47                                        01 Jun 1999    ピクロスNP Vol.3
# 48                                        01 Jun 1999    ピクロスNP Vol.3
# 49                                        01 Jun 1999    ピクロスNP Vol.3
# 50                                        01 Jun 1999    ピクロスNP Vol.3
# 51                                        01 Jun 1999    ピクロスNP Vol.3
# 52                                        01 Jun 1999    ピクロスNP Vol.3
# 53                                               None            None
#
#                                              EU Title   EU Release Date  \
# 0                                   Super Mario World          Apr 1992
# 1                                              F-Zero              None
# 2                                          Pilotwings          Jan 1993
# 3                                            Sim City          Sep 1992
# 4             The Legend of Zelda: A Link to the Past          Sep 1992
# 5                                         Mario Paint          Dec 1992
# 6                                    Super Mario Kart          Jan 1993
# 7                                            Starwing          Jun 1993
# 8                                    Nintendo Scope 6              1992
# 9                                         BattleClash          Mar 1993
# 10                              Super Mario All-Stars          Dec 1993
# 11                                     Yoshi's Safari              1993
# 12                                               None              None
# 13                                               None              None
# 14                                      Super Metroid          Jul 1994
# 15                                      Stunt Race FX          Oct 1994
# 16                                               None              None
# 17                               Kirby's Dream Course          Aug 1995
# 18                                Donkey Kong Country          Nov 1994
# 19                Super Mario World 2: Yoshi's Island          Oct 1995
# 20                              Mario's Super Picross              None
# 21                                      Tetris Attack              None
# 22          Donkey Kong Country 2: Diddy's Kong Quest          Dec 1995
# 23                                               None              None
# 24                                    Kirby's Fun Pak          Jan 1997
# 25                                               None              None
# 26                                               None              None
# 27  Donkey Kong Country 3: Dixie Kong's Double Tro...          Dec 1996
# 28                                               None              None
# 29                                               None              None
# 30                                               None              None
# 31                                               None              None
# 32                                               None              None
# 33                                               None              None
# 34                                               None              None
# 35                                               None              None
# 36                                  Super Punch-Out!!          Jan 1995
# 37                                               None              None
# 38                                               None              None
# 39                                               None              None
# 40                                               None              None
# 41                                               None              None
# 42                                               None              None
# 43                                               None              None
# 44                                       ピクロスNP Vol.2  Picross NP Vol.2
# 45                                       ピクロスNP Vol.2  Picross NP Vol.2
# 46                                               None              None
# 47                                       ピクロスNP Vol.2  Picross NP Vol.2
# 48                                       ピクロスNP Vol.2  Picross NP Vol.2
# 49                                       ピクロスNP Vol.2  Picross NP Vol.2
# 50                                       ピクロスNP Vol.2  Picross NP Vol.2
# 51                                       ピクロスNP Vol.2  Picross NP Vol.2
# 52                                       ピクロスNP Vol.2  Picross NP Vol.2
# 53                                               None              None
#
#    System                       Developer                   Genre  \
# 0     SFC                        Nintendo              Platformer
# 1     SFC                        Nintendo                  Racing
# 2     SFC                        Nintendo       Flight Simulation
# 3     SFC                 Nintendo, Maxis              Simulation
# 4     SFC                        Nintendo      Action / Adventure
# 5     SFC                        Nintendo             Art Utility
# 6     SFC                        Nintendo                  Racing
# 7     SFC             Nintendo / Argonaut                Shooting
# 8     SFC                        Nintendo               Light Gun
# 9     SFC  Nintendo / Intelligent Systems               Light Gun
# 10    SFC                        Nintendo  Platformer Compilation
# 11    SFC                        Nintendo               Light Gun
# 12    SFC                      Game Freak         Action / Puzzle
# 13    SFC             Intelligent Systems          Strategy / RPG
# 14    SFC  Nintendo / Intelligent Systems     Action / Platformer
# 15    SFC             Nintendo / Argonaut                  Racing
# 16    SFC                  HAL Laboratory                     RPG
# 17    SFC                  HAL Laboratory              Crazy Golf
# 18    SFC                            Rare              Platformer
# 19    SFC                        Nintendo              Platformer
# 20    SFC                         Jupiter                  Puzzle
# 21    SFC             Intelligent Systems                  Puzzle
# 22    SFC                            Rare              Platformer
# 23    SFC           Squaresoft / Nintendo                     RPG
# 24    SFC                  HAL Laboratory              Platformer
# 25    SFC             Intelligent Systems          Strategy / RPG
# 26    SFC                        Nintendo            Action / RPG
# 27    SFC                            Rare              Platformer
# 28    SFC                  HAL Laboratory      Fishing Simulation
# 29    SFC         Nintendo / Pax Softnica               Adventure
# 30    SFC         Nintendo / Pax Softnica               Adventure
# 31    SFC                        Nintendo         Action / Puzzle
# 32    SFC                  HAL Laboratory                  Puzzle
# 33    SFC                  Atelier Double         Action / Puzzle
# 34    SFC            Nintendo, Indieszero         Action / Puzzle
# 35    SFC             Intelligent Systems          Strategy / RPG
# 36    SFC                        Nintendo                  Boxing
# 37    SFC                        Nintendo               Adventure
# 38    SFC             Intelligent Systems                Strategy
# 39    SFC                        Nintendo                  Puzzle
# 40    SFC                        Nintendo                 Mahjong
# 41    SFC                            None                    None
# 42    SFC                            None                    None
# 43    SFC             Nintendo / T&E Soft         Action / Puzzle
# 44    SFC                         Jupiter                  Puzzle
# 45    SFC                         Jupiter                  Puzzle
# 46    SFC         Nintendo / Pax Softnica               Adventure
# 47    SFC                         Jupiter                  Puzzle
# 48    SFC                         Jupiter                  Puzzle
# 49    SFC                         Jupiter                  Puzzle
# 50    SFC                         Jupiter                  Puzzle
# 51    SFC                         Jupiter                  Puzzle
# 52    SFC                         Jupiter                  Puzzle
# 53    SFC                            None                    None
#
#                                  Series  \
# 0                    Super Mario Series
# 1                         F-Zero Series
# 2                     Pilotwings Series
# 3                        SimCity Series
# 4            The Legend of Zelda Series
# 5                    Super Mario Series
# 6                    Super Mario Series
# 7                       Star Fox Series
# 8                                  None
# 9                    BattleClash Series
# 10                   Super Mario Series
# 11                   Super Mario Series
# 12                   Super Mario Series
# 13                   Fire Emblem Series
# 14                       Metroid Series
# 15                                 None
# 16           EarthBound (Mother) Series
# 17                         Kirby Series
# 18                   Donkey Kong Series
# 19                   Super Mario Series
# 20  Super Mario Series / Picross Series
# 21                 Puzzle League Series
# 22                   Donkey Kong Series
# 23                   Super Mario Series
# 24                         Kirby Series
# 25                   Fire Emblem Series
# 26                                 None
# 27                   Donkey Kong Series
# 28               Bass Tsuri No.1 Series
# 29       Famicom Mukashi Banashi Series
# 30       Famicom Mukashi Banashi Series
# 31                   Super Mario Series
# 32                         Kirby Series
# 33                                 None
# 34                                 None
# 35                   Fire Emblem Series
# 36                   Punch-Out!! Series
# 37           Famicom Tantei Club Series
# 38                  Advance Wars Series
# 39                   Super Mario Series
# 40                       Mahjong Series
# 41                                 None
# 42                                 None
# 43                                 None
# 44                       Picross Series
# 45                       Picross Series
# 46                                 None
# 47                       Picross Series
# 48                       Picross Series
# 49                       Picross Series
# 50                       Picross Series
# 51                       Picross Series
# 52                       Picross Series
# 53                                 None
#
#                                              Producer  \
# 0                                    Shigeru Miyamoto
# 1                                    Shigeru Miyamoto
# 2                                    Shigeru Miyamoto
# 3                                    Shigeru Miyamoto
# 4                                    Shigeru Miyamoto
# 5                           (uncredited) Gunpei Yokoi
# 6                                    Shigeru Miyamoto
# 7                                    Shigeru Miyamoto
# 8                                        Gunpei Yokoi
# 9                                        Gunpei Yokoi
# 10                                   Shigeru Miyamoto
# 11                                               None
# 12                   Makoto Kanoh, Tsunekazu Ishihara
# 13                               Gunpei Yokoi (横井　軍平)
# 14                                       Makoto Kanoh
# 15                                   Shigeru Miyamoto
# 16                          / Director Shigesato Itoi
# 17                     Shigeru Miyamoto, Satoru Iwata
# 18                                               None
# 19                                   Shigeru Miyamoto
# 20                 Takashi Kawaguchi, Makoto Nakayama
# 21                                       Gunpei Yokoi
# 22                                       Gregg Mayles
# 23                                   Shigeru Miyamoto
# 24                     Satoru Iwata, Shigeru Miyamoto
# 25                                       Gunpei Yokoi
# 26                  (プロデューサー) Masayuki Uemura (上村 雅之)
# 27                                     Andrew Collard
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                    Tatsuya Hishida
# 32                                               None
# 33                                               None
# 34                                    Masayuki Uemura
# 35                                    Takehiro Izushi
# 36                                       Genyo Takeda
# 37                                               None
# 38                                    Takehiro Izushi
# 39                                       Gunpei Yokoi
# 40
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46   (制作) Takehiro Izushi (出石 武宏), Masahiro Tatemo...
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                                              Director
# 0                                      Takashi Tezuka
# 1                                                None
# 2                                    Tadashi Sugiyama
# 3                      Hideki Konno, Tadashi Sugiyama
# 4                                      Takashi Tezuka
# 5                                   Hirofumi Matsuoka
# 6                      Tadashi Sugiyama, Hideki Konno
# 7                                      Katsuya Eguchi
# 8                         Makoto Kano, Masao Yamamoto
# 9                        Makoto Kanoh, Masao Yamamoto
# 10                     and  Designer Shigeru Miyamoto
# 11                                               None
# 12                                               None
# 13                               Shouzou Kaga (加賀　昭三)
# 14                                    Yoshio Sakamoto
# 15                                    Tatsuya Hishida
# 16                         Producer /  Shigesato Itoi
# 17                                      Takashi Saito
# 18                                        Tim Stamper
# 19   Takashi Tezuka, Toshihiko Nakago, Shigefumi H...
# 20                                 Tsunekazu Ishihara
# 21                             Design  Makiko Tsujino
# 22                             Executive  Tim Stamper
# 23                 Chihiro Fujioka, Yoshihiko Maekawa
# 24                                   Masahiro Sakurai
# 25               Designer / Scenarist /  Shouzou Kaga
# 26          Sub  (サブ ディレクター) Mitsuhiro Takano (高野 充浩)
# 27                             Executive  Tim Stamper
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                     Eiko Takahashi
# 32                                               None
# 33                                               None
# 34                                    Masayasu Nakata
# 35                                               None
# 36                                        Makoto Wada
# 37                                               None
# 38                                      Toru Narihiro
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46   (監督) Taisuke Araki (荒木 泰介), Takahiro Harada (...
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None

# %%
df

# %%
snes_sales = open('snes_sales.txt', 'r')
games_and_sales = snes_sales.readlines()
games = games_and_sales[0:int(len(games_and_sales)/2)]
sales = games_and_sales[int(len(games_and_sales)/2):]

# %%
games_and_sales

# %%
df['WW Sales'] = [None] * len(df)
for i in range(len(df)):
    for j in range(len(games)):
        if df['US Title'][i] is not None:
            if games[j].split(' - ')[0].lower() in df['US Title'][i].lower():
                df['WW Sales'][i] = sales[j].split('\n')[0].replace(",", ".")

# %%
df

# %%
block

# %%
super_famicom_url = 'https://nindb.net/snes/games-jp.html'
game_list = get_games(super_famicom_url)
jap_name, jap_date, us_name, us_date, eu_name, eu_date = get_releasetable_data(super_famicom_url, game_list)

# %%
release_text

# %%
for name in image_names:
    if 'jp.png' in name:
        print(image_names.index(name))
    elif 'us.png' in name:
        print(image_names.index(name))
    elif 'eu.png' in name:
        print(image_names.index(name))

# %%
game = game_list[8]
driver.get(super_famicom_url)
driver.find_element_by_link_text(game).click()
flags = driver.find_elements_by_xpath('//td[@class="flag"]')


image_links = driver.find_elements_by_xpath("//img")

for element in image_links:
    flg = element.get_attribute("src")
    if flg is not None:
        print(flg)

# %%
df

# %%
director_list = str(devs[0].text).split('\n⌂ ')
director_value = ""
for i in range(1,len(director_list)):
    director_value = director_value + 
    print()

# %%
producer_value

# %%
game = "sim-city"

# %%
producer_flag = False
director_flag = False

devs

# %%
driver.get("http://kyoto-report.wikidot.com/" + game + "-credits")
devs = driver.find_elements_by_xpath('/html/body/div[1]/div/div[1]/div/div[2]/div/div[3]/p[2]')

producer_list = devs[0].text.split('\n⌂ ')
producer_value = ""

for k in range(1,len(producer_list)-1):
    producer_value = producer_value + producer_list[k].split('\n')[0] + ", "
    producer_value = producer_value + producer_list[len(producer_list)-1].split('\n')[0] 

if len(producer_list) == 2:
    producer_value = producer_list[1].split('\n')[0]

# %%
producer_list
# Out:
# ['Producer', 'Shigeru Miyamoto\nNintendo Co. Ltd.']

# %%
producer_value
# Out:
# 'Shigeru Miyamoto'

# %%
colors = pd.read_html('https://www.nintendo.co.jp/n02/dmg/index.html')

# %%
colors[0]
# Out:
#                          0          1          2             3              4
# 0                     ソフト名        発売日  カートリッジの分類       ゲームジャンル  NINTENDOPOWER
# 1    モバイルゴルフ＋モバイルアダプタGBセット  2001.5.11        NaN        ゴルフゲーム            NaN
# 2                      NaN        NaN        NaN           NaN            NaN
# 3   とっとこハム太郎２ ハムちゃんず大集合でちゅ  2001.4.21        NaN   おはなしアドベンチャー            NaN
# 4    ゼルダの伝説 ふしぎの木の実 〜時空の章〜  2001.2.27        NaN  アクションアドベンチャー            NaN
# ..                     ...        ...        ...           ...            ...
# 62                     テニス  1989.5.29        NaN          スポーツ            NaN
# 63                  アレイウェイ  1989.4.21        NaN         アクション            NaN
# 64                      役満  1989.4.21        NaN          テーブル            NaN
# 65                  ベースボール  1989.4.21        NaN          スポーツ            NaN
# 66              スーパーマリオランド  1989.4.21        NaN         アクション            NaN
#
# [67 rows x 5 columns]

# %%
colors[1]
# Out:
#                                                    0  \
# 0                                          カートリッジの分類
# 1                                          カートリッジの種類
# 2                                  ゲームボーイカラー専用カートリッジ
# 3                                 ゲームボーイ＆カラー共通カートリッジ
# 4  ［無印］は従来のゲームボーイ用ソフトです。全てのゲームボーイ本体で使用でき、ゲームボーイカラ...
#
#                                                    1          2          3
# 0                                          カートリッジの分類  カートリッジの分類  カートリッジの分類
# 1                                               製品概要    ゲームボーイ等  ゲームボーイカラー
# 2  ゲームボーイカラーおよびゲームボーイアドバンス専用ソフトです。カラー画面（32000色中最大...       使用不可        NaN
# 3  ゲームボーイ＆カラー共通ソフトです。ゲームボーイカラーおよびゲームボーイアドバンスはカラー画...        NaN        NaN
# 4  ［無印］は従来のゲームボーイ用ソフトです。全てのゲームボーイ本体で使用でき、ゲームボーイカラ...        NaN        NaN

# %%
def remove_non_ascii(text):

    return ''.join(i for i in text if ord(i)<128)

# %%
remove_non_ascii("Pùppò")
# Out:
# 'Ppp'
